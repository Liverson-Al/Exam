# %% [markdown]
# <a href="https://colab.research.google.com/github/Liverson-Al/Exam/blob/main/packets5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('Олег - Василиск')
# Out:
# Олег - Василиск

# %%
import numpy as np
import pandas as pd
normal_sample = np.random.normal(loc = 0.0, scale = 1.0, size = 10000)
random_sample = np.random.random(size = 10000)
gamma_sample = np.random.gamma(2, size = 10000)

df = pd.DataFrame({'normal': normal_sample,
                   'random': random_sample,
                   'gamma': gamma_sample})
df.head()
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.006164      0.499241      1.993878
# std        1.001575      0.290027      1.412219
# min       -4.262481      0.000068      0.005228
# 25%       -0.674829      0.250133      0.950323
# 50%       -0.000776      0.497154      1.666897
# 75%        0.685752      0.752627      2.673201
# max        3.594639      0.999885     12.315649

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure()

_ = plt.boxplot([df['normal'], df['random'], df['gamma'] ], whis = [0, 100])

# %%
dff = pd.DataFrame(data = df, columns =["normal", "random", "gamma"])
#sns.boxplot(x = None, y = None, data = dff)

bp = sns.boxplot(x="variable", y='value', data=pd.melt(dff), whis = [0,100])

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis = [0, 100])
ax2 = mpl_il.inset_axes(plt.gca(), width = '60%', height = '40%')

# %%
data = pd.read_csv('titanic.csv')
d = pd.DataFrame([["Sex", "Survived"]])
pd.pivot_table(data[["Sex", "Survived", "Age"]], 
               index = ["Sex"],
               columns = ["Survived"],
#               values = np.mean("Age"),
               aggfunc = "count")
# Out:
#           Age
# Survived    0    1
# Sex
# female     64  197
# male      360   93

# %%
anime = pd.read_csv('anime.csv')
anime
# Out:
#                                                   Title      Production  \
# 0                                    Shingeki no Kyojin      Wit Studio
# 1                      Fullmetal Alchemist: Brotherhood           Bones
# 2                                      Sword Art Online    A-1 Pictures
# 3                                         One Punch Man        Madhouse
# 4                                 Boku no Hero Academia           Bones
# ...                                                 ...             ...
# 1987                                 Dog Days' Specials      Seven Arcs
# 1988                             Bleach: Gotei 13 Omake               -
# 1989                                       Brain Powerd         Sunrise
# 1990  Mobile Suit Gundam: Iron-Blooded Orphans - Urð...  Sunrise Beyond
# 1991                                   Burn Up Scramble     AIC Spirits
#
#      Episodes       Source                                  Genre  \
# ...
