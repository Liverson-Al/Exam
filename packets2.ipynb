# %% [markdown]
# <a href="https://colab.research.google.com/github/Liverson-Al/Exam/blob/main/packets2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt


from collections import Counter

#with open('orwell_1984.txt', encoding='utf8') as text:
#  words_len = [len(word) for word in text.read().split()]
#words_len
#longest_word_length = max(words_len)
#plt.hist(words_len, bins = longest_word_length)
#plt.show()




import math

x = [-7.0,-6.8,-6.6,-6.3,-6.1,-5.9,-5.7,-5.5,-5.3,-5.1,-4.9,-4.7,-4.5,-4.3,-4.1,-3.9,
     -3.7,-3.5,-3.3,-3.1,-2.9,-2.7,-2.5,-2.3,-2.1,-1.9,-1.7,-1.5,-1.3,-1.1,-0.9,-0.7,-0.5,-0.3,-0.1,0.1]
sin_y = [math.sin(t) for t in x]
cos_y = [math.sin(t) for t in x]
plt.plot(x, [1]*len(x), '--', x, [-1]*len(x), '--', x, sin_y, x, cos_y)
plt.show()

# %%
histogram = [words_len[words_length] for words_length in range(0, longest_word_length +1)]
histogram

plt.hist(list(range(0, longest_word_length+1)), weights = histogram, bins = longest_word_length+1, orientation = 'horizontal')
plt.xlabel('кол-во слов данной длины')
plt.ylabel('длина слова')

plt.show()

#for words_length in range(0, longest_word_length+1):
#  bin_height = histogram[words_length]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)

x = [-3,-2,-1,0,1,2,3]
y = [9,4,1,0,1,4,9]

fig.set()

ax.plot(x, y, color = 'black', linewidth = 3)
ax.scatter([0,1,2,3,4], [1,3,8,12,29], color = 'blue', marker = '*')
#
#ax.set_xlim([-10,10])
#ax.set_ylim([-2,2])
#
#ax.set_xlabel('x')
#ax.set_ylabel('y')
#
# ax.set_title('bla bla')

plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax=plt.subplots(figsize = (5,3))

ax.plot(x, y, color = 'black', linewidth = 3)
ax.scatter([0,1,2,3,4], [1,3,8,12,10], color = 'blue', marker = '*')

plt.show()

# %%
from math import *

def Temperature(t: float) -> float:
  return (atan(-0.0012*t**3+0.4*t**2+0.616*t+6120)+0.65*sin(0.24*t+1.23)-0.27*cos(0.21*t-0.17)-(sin(0.34*t+0.16))/(1+0.03*(t-370.5)**2))

x = range(0, 1000)
#for i in range(0, 1000):
#  y.append(Temperature(i))
y = [Temperature(t) for t in x]
plt.plot(x,y)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(
    nrows = 1, ncols = 2,
    figsize = (8,4)
)
